# %%
import requests
from bs4 import BeautifulSoup
import csv

# PubMed API URL 및 검색 쿼리 설정
base_url_search = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi"
base_url_summary = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esummary.fcgi"

# 수정된 쿼리
query = '''((("IgA Nephropathy"[Mesh]) OR "Berger's Disease"[tiab] OR "IgA glomerulonephritis"[tiab] OR "IgA nephritis"[tiab]) AND 
(("Immunosuppressive Agents"[Mesh]) OR "immunosuppressive therapy"[tiab] OR "immunomodulators"[tiab] OR "immunotherapy"[tiab])) AND 
(("Infant"[Mesh]) OR "Child"[Mesh] OR "Adolescent"[Mesh] OR "Pediatrics"[Mesh] OR "children"[tiab] OR "infants"[tiab] OR "adolescents"[tiab]))'''

# API 요청 파라미터 설정
params_search = {
    "db": "pubmed",
    "term": query,
    "retmode": "xml",
    "retmax": 100  # 가져올 최대 논문 수
}

# 검색 요청
response_search = requests.get(base_url_search, params=params_search)

# 논문 제목을 저장할 리스트
titles = []

# 검색 성공 여부 확인
if response_search.status_code == 200:
    soup_search = BeautifulSoup(response_search.content, "lxml")
    
    # PubMed ID (PMID) 리스트 가져오기
    pmid_list = [id_tag.text for id_tag in soup_search.find_all("id")]
    
    # PMID 리스트를 이용해 논문 제목 가져오기
    params_summary = {
        "db": "pubmed",
        "id": ",".join(pmid_list),
        "retmode": "xml"
    }
    
    response_summary = requests.get(base_url_summary, params=params_summary)
    
    if response_summary.status_code == 200:
        soup_summary = BeautifulSoup(response_summary.content, "lxml")
        
        # 제목 추출
        titles = [item.text for item in soup_summary.find_all("item", {"name": "Title"})]
        
        # CSV 파일로 저장
        csv_file_path = '/Users/myo/Desktop/Kangs/pubmed_result.csv'
        
        with open(csv_file_path, mode='w', newline='', encoding='utf-8') as file:
            writer = csv.writer(file)
            writer.writerow(['Title'])  # 헤더 작성
            for title in titles:
                writer.writerow([title])  # 각 제목을 새로운 행에 기록
                
        print(f"Results saved to {csv_file_path}")
    else:
        print(f"Failed to retrieve summaries: {response_summary.status_code}")
else:
    print(f"Failed to retrieve search results: {response_search.status_code}")
# Out:
# /var/folders/cm/spz3y4m11_v49my31w8gppj00000gn/T/ipykernel_4447/299416093.py:30: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   soup_search = BeautifulSoup(response_search.content, "lxml")
# Results saved to /Users/myo/Desktop/Kangs/pubmed_result.csv
# /var/folders/cm/spz3y4m11_v49my31w8gppj00000gn/T/ipykernel_4447/299416093.py:45: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   soup_summary = BeautifulSoup(response_summary.content, "lxml")

# %%
# Out:
# <?xml version="1.0" encoding="UTF-8" ?>
# <!DOCTYPE eSummaryResult PUBLIC "-//NLM//DTD esummary v1 20041029//EN" "https://eutils.ncbi.nlm.nih.gov/eutils/dtd/20041029/esummary-v1.dtd">
# <html>
#  <body>
#   <esummaryresult>
#    <docsum>
#     <id>
#      36195856
#     </id>
#     <item name="PubDate" type="Date">
#      2022 Oct 4
#     </item>
#     <item name="EPubDate" type="Date">
#      2022 Oct 4
#     </item>
#     <item name="Source" type="String">
#      BMC Pediatr
#     </item>
#     <item name="AuthorList" type="List">
#      <item name="Author" type="String">
#       Butzer S
#      </item>
#      <item name="Author" type="String">
#       Hennies I
#      </item>
#      <item name="Author" type="String">
#       Gimpel C
#      </item>
#      <item name="Author" type="String">
#       Gellermann J
#      </item>
#      <item name="Author" type="String">
#       Schalk G
#      </item>
#      <item name="Author" type="String">
#       König S
#      </item>
#      <item name="Author" type="String">
#       Büscher AK
#      </item>
#      <item name="Author" type="String">
#       Lemke A
#      </item>
#      <item name="Author" type="String">
#       Pohl M
#      </item>
#     </item>
#     <item name="LastAuthor" type="String">
#      Pohl M
#     </item>
#     <item name="Title" type="String">
#      Early clinical course of biopsy-proven IgA vasculitis nephritis.
#     </item>
#     <item name="Volume" type="String">
#      22
#     </item>
#     <item name="Issue" type="String">
#      1
#     </item>
#     <item name="Pages" type="String">
#      570
#     </item>
#     <item name="LangList" type="List">
#      <item name="Lang" type="String">
#       English
#      </item>
#     </item>
#     <item name="NlmUniqueID" type="String">
#      100967804
#     </item>
#     <item name="ISSN" type="String">
#     </item>
#     <item name="ESSN" type="String">
#      1471-2431
#     </item>
#     <item name="PubTypeList" type="List">
#      <item name="PubType" type="String">
#       Journal Article
#      </item>
#      <item name="PubType" type="String">
#       Multicenter Study
#      </item>
#     </item>
#     <item name="RecordStatus" type="String">
#      PubMed - indexed for MEDLINE
#     </item>
#     <item name="PubStatus" type="String">
#      epublish
#     </item>
#     <item name="ArticleIds" type="List">
#      <item name="pubmed" type="String">
#       36195856
#      </item>
#      <item name="pmc" type="String">
#       PMC9531371
#      </item>
#      <item name="pmcid" type="String">
#       pmc-id: PMC9531371;
#      </item>
#      <item name="doi" type="String">
#       10.1186/s12887-022-03611-9
#      </item>
#      <item name="pii" type="String">
#       10.1186/s12887-022-03611-9
#      </item>
#     </item>
#     <item name="DOI" type="String">
#      10.1186/s12887-022-03611-9
#     </item>
#     <item name="History" type="List">
#      <item name="received" type="Date">
#       2021/11/08 00:00
#      </item>
#      <item name="accepted" type="Date">
#       2022/09/14 00:00
#      </item>
#      <item name="entrez" type="Date">
#       2022/10/04 23:34
#      </item>
#      <item name="pubmed" type="Date">
#       2022/10/05 06:00
#      </item>
#      <item name="medline" type="Date">
#       2022/10/07 06:00
#      </item>
#      <item name="pmc-release" type="Date">
#       2022/10/04 00:00
#      </item>
#     </item>
#     <item name="References" type="List">
#     </item>
#     <item name="HasAbstract" type="Integer">
#      1
#     </item>
#     <item name="PmcRefCount" type="Integer">
#      34
#     </item>
#     <item name="FullJournalName" type="String">
#      BMC pediatrics
#     </item>
#     <item name="ELocationID" type="String">
#      doi: 10.1186/s12887-022-03611-9
#     </item>
#     <item name="SO" type="String">
#      2022 Oct 4;22(1):570
#     </item>
#    </docsum>
#    <docsum>
#     <id>
#      30955086
#     </id>
#     <item name="PubDate" type="Date">
#      2019 Aug
#     </item>
#     <item name="EPubDate" type="Date">
#      2019 Apr 6
#     </item>
#     <item name="Source" type="String">
#      Pediatr Nephrol
#     </item>
#     <item name="AuthorList" type="List">
#      <item name="Author" type="String">
#       Koskela M
#      </item>
#      <item name="Author" type="String">
#       Jahnukainen T
#      </item>
#      <item name="Author" type="String">
#       Endén K
#      </item>
#      <item name="Author" type="String">
#       Arikoski P
#      </item>
#      <item name="Author" type="String">
#       Kataja J
#      </item>
#      <item name="Author" type="String">
#       Nuutinen M
#      </item>
#      <item name="Author" type="String">
#       Ylinen E
#      </item>
#     </item>
#     <item name="LastAuthor" type="String">
#      Ylinen E
#     </item>
#     <item name="Title" type="String">
#      Methylprednisolone or cyclosporine a in the treatment of Henoch-Schönlein nephritis: a nationwide study.
#     </item>
#     <item name="Volume" type="String">
#      34
#     </item>
#     <item name="Issue" type="String">
#      8
#     </item>
#     <item name="Pages" type="String">
#      1447-1456
#     </item>
#     <item name="LangList" type="List">
#      <item name="Lang" type="String">
#       English
#      </item>
#     </item>
#     <item name="NlmUniqueID" type="String">
#      8708728
#     </item>
#     <item name="ISSN" type="String">
#      0931-041X
#     </item>
#     <item name="ESSN" type="String">
#      1432-198X
#     </item>
#     <item name="PubTypeList" type="List">
#      <item name="PubType" type="String">
#       Journal Article
#      </item>
#     </item>
#     <item name="RecordStatus" type="String">
#      PubMed - indexed for MEDLINE
#     </item>
#     <item name="PubStatus" type="String">
#      ppublish+epublish
#     </item>
#     <item name="ArticleIds" type="List">
#      <item name="pubmed" type="String">
#       30955086
#      </item>
#      <item name="doi" type="String">
#       10.1007/s00467-019-04238-2
#      </item>
#      <item name="pii" type="String">
#       10.1007/s00467-019-04238-2
#      </item>
#     </item>
#     <item name="DOI" type="String">
#      10.1007/s00467-019-04238-2
#     </item>
#     <item name="History" type="List">
#      <item name="received" type="Date">
#       2018/11/20 00:00
#      </item>
#      <item name="accepted" type="Date">
#       2019/03/14 00:00
#      </item>
#      <item name="revised" type="Date">
#       2019/02/10 00:00
#      </item>
#      <item name="pubmed" type="Date">
#       2019/04/08 06:00
#      </item>
#      <item name="medline" type="Date">
#       2020/06/06 06:00
#      </item>
#      <item name="entrez" type="Date">
#       2019/04/08 06:00
#      </item>
#     </item>
#     <item name="References" type="List">
#     </item>
#     <item name="HasAbstract" type="Integer">
#      1
#     </item>
#     <item name="PmcRefCount" type="Integer">
#      0
#     </item>
#     <item name="FullJournalName" type="String">
#      Pediatric nephrology (Berlin, Germany)
#     </item>
#     <item name="ELocationID" type="String">
#      doi: 10.1007/s00467-019-04238-2
#     </item>
#     <item name="SO" type="String">
#      2019 Aug;34(8):1447-1456
#     </item>
#    </docsum>
#    <docsum>
#     <id>
#      17530298
#     </id>
#     <item name="PubDate" type="Date">
#      2007 Aug
#     </item>
#     <item name="EPubDate" type="Date">
#      2007 May 26
#     </item>
#     <item name="Source" type="String">
#      Pediatr Nephrol
#     </item>
#     <item name="AuthorList" type="List">
#      <item name="Author" type="String">
#       Shenoy M
#      </item>
#      <item name="Author" type="String">
#       Ognjanovic MV
#      </item>
#      <item name="Author" type="String">
#       Coulthard MG
#      </item>
#     </item>
#     <item name="LastAuthor" type="String">
#      Coulthard MG
#     </item>
#     <item name="Title" type="String">
#      Treating severe Henoch-Schönlein and IgA nephritis with plasmapheresis alone.
#     </item>
#     <item name="Volume" type="String">
#      22
#     </item>
#     <item name="Issue" type="String">
#      8
#     </item>
#     <item name="Pages" type="String">
#      1167-71
#     </item>
#     <item name="LangList" type="List">
#      <item name="Lang" type="String">
#       English
#      </item>
#     </item>
#     <item name="NlmUniqueID" type="String">
#      8708728
#     </item>
#     <item name="ISSN" type="String">
#      0931-041X
#     </item>
#     <item name="ESSN" type="String">
#     </item>
#     <item name="PubTypeList" type="List">
#      <item name="PubType" type="String">
#       Journal Article
#      </item>
#     </item>
#     <item name="RecordStatus" type="String">
#      PubMed - indexed for MEDLINE
#     </item>
#     <item name="PubStatus" type="String">
#      ppublish+epublish
#     </item>
#     <item name="ArticleIds" type="List">
#      <item name="pubmed" type="String">
#       17530298
#      </item>
#      <item name="doi" type="String">
#       10.1007/s00467-007-0498-y
#      </item>
#     </item>
#     <item name="DOI" type="String">
#      10.1007/s00467-007-0498-y
#     </item>
#     <item name="History" type="List">
#      <item name="received" type="Date">
#       2006/11/09 00:00
#      </item>
#      <item name="accepted" type="Date">
#       2007/03/27 00:00
#      </item>
#      <item name="revised" type="Date">
#       2007/03/24 00:00
#      </item>
#      <item name="pubmed" type="Date">
#       2007/05/29 09:00
#      </item>
#      <item name="medline" type="Date">
#       2007/09/06 09:00
#      </item>
#      <item name="entrez" type="Date">
#       2007/05/29 09:00
#      </item>
#     </item>
#     <item name="References" type="List">
#     </item>
#     <item name="HasAbstract" type="Integer">
#      1
#     </item>
#     <item name="PmcRefCount" type="Integer">
#      0
#     </item>
#     <item name="FullJournalName" type="String">
#      Pediatric nephrology (Berlin, Germany)
#     </item>
#     <item name="ELocationID" type="String">
#     </item>
#     <item name="SO" type="String">
#      2007 Aug;22(8):1167-71
#     </item>
#    </docsum>
#    <docsum>
#     <id>
#      14726626
#     </id>
#     <item name="PubDate" type="Date">
#      2004 Jan-Feb
#     </item>
#     <item name="EPubDate" type="Date">
#      2004 Jan 14
#     </item>
#     <item name="Source" type="String">
#      Am J Nephrol
#     </item>
#     <item name="AuthorList" type="List">
#      <item name="Author" type="String">
#       Kawasaki Y
#      </item>
#      <item name="Author" type="String">
#       Suzuki J
#      </item>
#      <item name="Author" type="String">
#       Sakai N
#      </item>
#      <item name="Author" type="String">
#       Etoh S
#      </item>
#      <item name="Author" type="String">
#       Murai H
#      </item>
#      <item name="Author" type="String">
#       Nozawa R
#      </item>
#      <item name="Author" type="String">
#       Suzuki H
#      </item>
#     </item>
#     <item name="LastAuthor" type="String">
#      Suzuki H
#     </item>
#     <item name="Title" type="String">
#      Efficacy of prednisolone and mizoribine therapy for diffuse IgA nephropathy.
#     </item>
#     <item name="Volume" type="String">
#      24
#     </item>
#     <item name="Issue" type="String">
#      1
#     </item>
#     <item name="Pages" type="String">
#      147-53
#     </item>
#     <item name="LangList" type="List">
#      <item name="Lang" type="String">
#       English
#      </item>
#     </item>
#     <item name="NlmUniqueID" type="String">
#      8109361
#     </item>
#     <item name="ISSN" type="String">
#      0250-8095
#     </item>
#     <item name="ESSN" type="String">
#     </item>
#     <item name="PubTypeList" type="List">
#      <item name="PubType" type="String">
#       Clinical Trial
#      </item>
#      <item name="PubType" type="String">
#       Journal Article
#      </item>
#     </item>
#     <item name="RecordStatus" type="String">
#      PubMed - indexed for MEDLINE
#     </item>
#     <item name="PubStatus" type="String">
#      ppublish+epublish
#     </item>
#     <item name="ArticleIds" type="List">
#      <item name="pubmed" type="String">
#       14726626
#      </item>
#      <item name="doi" type="String">
#       10.1159/000076243
#      </item>
#      <item name="pii" type="String">
#       76243
#      </item>
#     </item>
#     <item name="DOI" type="String">
#      10.1159/000076243
#     </item>
#     <item name="History" type="List">
#      <item name="received" type="Date">
#       2003/07/24 00:00
#      </item>
#      <item name="accepted" type="Date">
#       2003/10/30 00:00
#      </item>
#      <item name="pubmed" type="Date">
#       2004/01/17 05:00
#      </item>
#      <item name="medline" type="Date">
#       2004/06/04 05:00
#      </item>
#      <item name="entrez" type="Date">
#       2004/01/17 05:00
#      </item>
#     </item>
#     <item name="References" type="List">
#     </item>
#     <item name="HasAbstract" type="Integer">
#      1
#     </item>
#     <item name="PmcRefCount" type="Integer">
#      0
#     </item>
#     <item name="FullJournalName" type="String">
#      American journal of nephrology
#     </item>
#     <item name="ELocationID" type="String">
#     </item>
#     <item name="SO" type="String">
#      2004 Jan-Feb;24(1):147-53
#     </item>
#    </docsum>
#    <docsum>
#     <id>
#      11004910
#     </id>
#     <item name="PubDate" type="Date">
#      2000 Aug 25
#     </item>
#     <item name="EPubDate" type="Date">
#     </item>
#     <item name="Source" type="String">
#      Dtsch Med Wochenschr
#     </item>
#     <item name="AuthorList" type="List">
#      <item name="Author" type="String">
#       Risler T
#      </item>
#      <item name="Author" type="String">
#       Braun N
#      </item>
#     </item>
#     <item name="LastAuthor" type="String">
#      Braun N
#     </item>
#     <item name="Title" type="String">
#      [Treatment of IGA nephritis].
#     </item>
#     <item name="Volume" type="String">
#      125
#     </item>
#     <item name="Issue" type="String">
#      34-35
#     </item>
#     <item name="Pages" type="String">
#      996
#     </item>
#     <item name="LangList" type="List">
#      <item name="Lang" type="String">
#       German
#      </item>
#     </item>
#     <item name="NlmUniqueID" type="String">
#      0006723
#     </item>
#     <item name="ISSN" type="String">
#      0012-0472
#     </item>
#     <item name="ESSN" type="String">
#     </item>
#     <item name="PubTypeList" type="List">
#      <item name="PubType" type="String">
#       Editorial
#      </item>
#     </item>
#     <item name="RecordStatus" type="String">
#      PubMed - indexed for MEDLINE
#     </item>
#     <item name="PubStatus" type="String">
#      ppublish
#     </item>
#     <item name="ArticleIds" type="List">
#      <item name="pubmed" type="String">
#       11004910
#      </item>
#     </item>
#     <item name="History" type="List">
#      <item name="pubmed" type="Date">
#       2000/09/27 11:00
#      </item>
#      <item name="medline" type="Date">
#       2000/10/07 11:01
#      </item>
#      <item name="entrez" type="Date">
#       2000/09/27 11:00
#      </item>
#     </item>
#     <item name="References" type="List">
#     </item>
#     <item name="HasAbstract" type="Integer">
#      0
#     </item>
#     <item name="PmcRefCount" type="Integer">
#      0
#     </item>
#     <item name="FullJournalName" type="String">
#      Deutsche medizinische Wochenschrift (1946)
#     </item>
#     <item name="ELocationID" type="String">
#     </item>
#     <item name="SO" type="String">
#      2000 Aug 25;125(34-35):996
#     </item>
#    </docsum>
#    <docsum>
#     <id>
#      10480220
#     </id>
#     <item name="PubDate" type="Date">
#      1999 Aug
#     </item>
#     <item name="EPubDate" type="Date">
#     </item>
#     <item name="Source" type="String">
#      Clin Nephrol
#     </item>
#     <item name="AuthorList" type="List">
#      <item name="Author" type="String">
#       Woo KT
#      </item>
#      <item name="Author" type="String">
#       Chiang GS
#      </item>
#      <item name="Author" type="String">
#       Pall A
#      </item>
#      <item name="Author" type="String">
#       Tan PH
#      </item>
#      <item name="Author" type="String">
#       Lau YK
#      </item>
#      <item name="Author" type="String">
#       Chin YM
#      </item>
#     </item>
#     <item name="LastAuthor" type="String">
#      Chin YM
#     </item>
#     <item name="Title" type="String">
#      The changing pattern of glomerulonephritis in Singapore over the past two decades.
#     </item>
#     <item name="Volume" type="String">
#      52
#     </item>
#     <item name="Issue" type="String">
#      2
#     </item>
#     <item name="Pages" type="String">
#      96-102
#     </item>
#     <item name="LangList" type="List">
#      <item name="Lang" type="String">
#       English
#      </item>
#     </item>
#     <item name="NlmUniqueID" type="String">
#      0364441
#     </item>
#     <item name="ISSN" type="String">
#      0301-0430
#     </item>
#     <item name="ESSN" type="String">
#     </item>
#     <item name="PubTypeList" type="List">
#      <item name="PubType" type="String">
#       Journal Article
#      </item>
#     </item>
#     <item name="RecordStatus" type="String">
#      PubMed - indexed for MEDLINE
#     </item>
#     <item name="PubStatus" type="String">
#      ppublish
#     </item>
#     <item name="ArticleIds" type="List">
#      <item name="pubmed" type="String">
#       10480220
#      </item>
#     </item>
#     <item name="History" type="List">
#      <item name="pubmed" type="Date">
#       1999/09/10 00:00
#      </item>
#      <item name="medline" type="Date">
#       1999/09/10 00:01
#      </item>
#      <item name="entrez" type="Date">
#       1999/09/10 00:00
#      </item>
#     </item>
#     <item name="References" type="List">
#     </item>
#     <item name="HasAbstract" type="Integer">
#      1
#     </item>
#     <item name="PmcRefCount" type="Integer">
#      0
#     </item>
#     <item name="FullJournalName" type="String">
#      Clinical nephrology
#     </item>
#     <item name="ELocationID" type="String">
#     </item>
#     <item name="SO" type="String">
#      1999 Aug;52(2):96-102
#     </item>
#    </docsum>
#    <docsum>
#     <id>
#      10385482
#     </id>
#     <item name="PubDate" type="Date">
#      1999 Jan
#     </item>
#     <item name="EPubDate" type="Date">
#     </item>
#     <item name="Source" type="String">
#      J Lab Clin Med
#     </item>
#     <item name="AuthorList" type="List">
#      <item name="Author" type="String">
#       Lin CY
#      </item>
#      <item name="Author" type="String">
#       Ku FM
#      </item>
#      <item name="Author" type="String">
#       Kuo YC
#      </item>
#      <item name="Author" type="String">
#       Chen CF
#      </item>
#      <item name="Author" type="String">
#       Chen WP
#      </item>
#      <item name="Author" type="String">
#       Chen A
#      </item>
#      <item name="Author" type="String">
#       Shiao MS
#      </item>
#     </item>
#     <item name="LastAuthor" type="String">
#      Shiao MS
#     </item>
#     <item name="Title" type="String">
#      Inhibition of activated human mesangial cell proliferation by the natural product of Cordyceps sinensis (H1-A): an implication for treatment of IgA mesangial nephropathy.
#     </item>
#     <item name="Volume" type="String">
#      133
#     </item>
#     <item name="Issue" type="String">
#      1
#     </item>
#     <item name="Pages" type="String">
#      55-63
#     </item>
#     <item name="LangList" type="List">
#      <item name="Lang" type="String">
#       English
#      </item>
#     </item>
#     <item name="NlmUniqueID" type="String">
#      0375375
#     </item>
#     <item name="ISSN" type="String">
#      0022-2143
#     </item>
#     <item name="ESSN" type="String">
#     </item>
#     <item name="PubTypeList" type="List">
#      <item name="PubType" type="String">
#       Journal Article
#      </item>
#     </item>
#     <item name="RecordStatus" type="String">
#      PubMed - indexed for MEDLINE
#     </item>
#     <item name="PubStatus" type="String">
#      ppublish
#     </item>
#     <item name="ArticleIds" type="List">
#      <item name="pubmed" type="String">
#       10385482
#      </item>
#      <item name="doi" type="String">
#       10.1053/lc.1999.v133.a94239
#      </item>
#      <item name="pii" type="String">
#       S0022-2143(99)00002-5
#      </item>
#     </item>
#     <item name="DOI" type="String">
#      10.1053/lc.1999.v133.a94239
#     </item>
#     <item name="History" type="List">
#      <item name="pubmed" type="Date">
#       1999/06/29 00:00
#      </item>
#      <item name="medline" type="Date">
#       1999/06/29 00:01
#      </item>
#      <item name="entrez" type="Date">
#       1999/06/29 00:00
#      </item>
#     </item>
#     <item name="References" type="List">
#     </item>
#     <item name="HasAbstract" type="Integer">
#      1
#     </item>
#     <item name="PmcRefCount" type="Integer">
#      0
#     </item>
#     <item name="FullJournalName" type="String">
#      The Journal of laboratory and clinical medicine
#     </item>
#     <item name="ELocationID" type="String">
#     </item>
#     <item name="SO" type="String">
#      1999 Jan;133(1):55-63
#     </item>
#    </docsum>
#    <docsum>
#     <id>
#      8941029
#     </id>
#     <item name="PubDate" type="Date">
#      1996 Nov
#     </item>
#     <item name="EPubDate" type="Date">
#     </item>
#     <item name="Source" type="String">
#      Clin Pharmacol Ther
#     </item>
#     <item name="AuthorList" type="List">
#      <item name="Author" type="String">
#       Faedda R
#      </item>
#      <item name="Author" type="String">
#       Pirisi M
#      </item>
#      <item name="Author" type="String">
#       Satta A
#      </item>
#      <item name="Author" type="String">
#       Bosincu L
#      </item>
#      <item name="Author" type="String">
#       Bartoli E
#      </item>
#     </item>
#     <item name="LastAuthor" type="String">
#      Bartoli E
#     </item>
#     <item name="Title" type="String">
#      Immunosuppressive treatment of Berger's disease.
#     </item>
#     <item name="Volume" type="String">
#      60
#     </item>
#     <item name="Issue" type="String">
#      5
#     </item>
#     <item name="Pages" type="String">
#      561-7
#     </item>
#     <item name="LangList" type="List">
#      <item name="Lang" type="String">
#       English
#      </item>
#     </item>
#     <item name="NlmUniqueID" type="String">
#      0372741
#     </item>
#     <item name="ISSN" type="String">
#      0009-9236
#     </item>
#     <item name="ESSN" type="String">
#     </item>
#     <item name="PubTypeList" type="List">
#      <item name="PubType" type="String">
#       Journal Article
#      </item>
#     </item>
#     <item name="RecordStatus" type="String">
#      PubMed - indexed for MEDLINE
#     </item>
#     <item name="PubStatus" type="String">
#      ppublish
#     </item>
#     <item name="ArticleIds" type="List">
#      <item name="pubmed" type="String">
#       8941029
#      </item>
#      <item name="doi" type="String">
#       10.1016/S0009-9236(96)90152-6
#      </item>
#      <item name="pii" type="String">
#       S0009-9236(96)90152-6
#      </item>
#     </item>
#     <item name="DOI" type="String">
#      10.1016/S0009-9236(96)90152-6
#     </item>
#     <item name="History" type="List">
#      <item name="pubmed" type="Date">
#       1996/11/01 00:00
#      </item>
#      <item name="medline" type="Date">
#       1996/11/01 00:01
#      </item>
#      <item name="entrez" type="Date">
#       1996/11/01 00:00
#      </item>
#     </item>
#     <item name="References" type="List">
#     </item>
#     <item name="HasAbstract" type="Integer">
#      1
#     </item>
#     <item name="PmcRefCount" type="Integer">
#      0
#     </item>
#     <item name="FullJournalName" type="String">
#      Clinical pharmacology and therapeutics
#     </item>
#     <item name="ELocationID" type="String">
#     </item>
#     <item name="SO" type="String">
#      1996 Nov;60(5):561-7
#     </item>
#    </docsum>
#    <docsum>
#     <id>
#      8643167
#     </id>
#     <item name="PubDate" type="Date">
#      1995 Nov
#     </item>
#     <item name="EPubDate" type="Date">
#     </item>
#     <item name="Source" type="String">
#      Nephrol Dial Transplant
#     </item>
#     <item name="AuthorList" type="List">
#      <item name="Author" type="String">
#       Roccatello D
#      </item>
#      <item name="Author" type="String">
#       Ferro M
#      </item>
#      <item name="Author" type="String">
#       Coppo R
#      </item>
#      <item name="Author" type="String">
#       Giraudo G
#      </item>
#      <item name="Author" type="String">
#       Quattrocchio G
#      </item>
#      <item name="Author" type="String">
#       Piccoli G
#      </item>
#     </item>
#     <item name="LastAuthor" type="String">
#      Piccoli G
#     </item>
#     <item name="Title" type="String">
#      Report on intensive treatment of extracapillary glomerulonephritis with focus on crescentic IgA nephropathy.
#     </item>
#     <item name="Volume" type="String">
#      10
#     </item>
#     <item name="Issue" type="String">
#      11
#     </item>
#     <item name="Pages" type="String">
#      2054-9
#     </item>
#     <item name="LangList" type="List">
#      <item name="Lang" type="String">
#       English
#      </item>
#     </item>
#     <item name="NlmUniqueID" type="String">
#      8706402
#     </item>
#     <item name="ISSN" type="String">
#      0931-0509
#     </item>
#     <item name="ESSN" type="String">
#     </item>
#     <item name="PubTypeList" type="List">
#      <item name="PubType" type="String">
#       Journal Article
#      </item>
#     </item>
#     <item name="RecordStatus" type="String">
#      PubMed - indexed for MEDLINE
#     </item>
#     <item name="PubStatus" type="String">
#      ppublish
#     </item>
#     <item name="ArticleIds" type="List">
#      <item name="pubmed" type="String">
#       8643167
#      </item>
#     </item>
#     <item name="History" type="List">
#      <item name="pubmed" type="Date">
#       1995/11/01 00:00
#      </item>
#      <item name="medline" type="Date">
#       1995/11/01 00:01
#      </item>
#      <item name="entrez" type="Date">
#       1995/11/01 00:00
#      </item>
#     </item>
#     <item name="References" type="List">
#     </item>
#     <item name="HasAbstract" type="Integer">
#      1
#     </item>
#     <item name="PmcRefCount" type="Integer">
#      0
#     </item>
#     <item name="FullJournalName" type="String">
#      Nephrology, dialysis, transplantation : official publication of the European Dialysis and Transplant Association - European Renal Association
#     </item>
#     <item name="ELocationID" type="String">
#     </item>
#     <item name="SO" type="String">
#      1995 Nov;10(11):2054-9
#     </item>
#    </docsum>
#    <docsum>
#     <id>
#      8072976
#     </id>
#     <item name="PubDate" type="Date">
#      1994 Apr 16
#     </item>
#     <item name="EPubDate" type="Date">
#     </item>
#     <item name="Source" type="String">
#      Presse Med
#     </item>
#     <item name="AuthorList" type="List">
#      <item name="Author" type="String">
#       Cartron J
#      </item>
#      <item name="Author" type="String">
#       Blesson S
#      </item>
#      <item name="Author" type="String">
#       Celton JL
#      </item>
#      <item name="Author" type="String">
#       Berthélémé JP
#      </item>
#      <item name="Author" type="String">
#       Broyer M
#      </item>
#      <item name="Author" type="String">
#       Niaudet P
#      </item>
#     </item>
#     <item name="LastAuthor" type="String">
#      Niaudet P
#     </item>
#     <item name="Title" type="String">
#      [Hemolytic anemia after kidney transplantation].
#     </item>
#     <item name="Volume" type="String">
#      23
#     </item>
#     <item name="Issue" type="String">
#      15
#     </item>
#     <item name="Pages" type="String">
#      707-9
#     </item>
#     <item name="LangList" type="List">
#      <item name="Lang" type="String">
#       French
#      </item>
#     </item>
#     <item name="NlmUniqueID" type="String">
#      8302490
#     </item>
#     <item name="ISSN" type="String">
#      0755-4982
#     </item>
#     <item name="ESSN" type="String">
#     </item>
#     <item name="PubTypeList" type="List">
#      <item name="PubType" type="String">
#       Journal Article
#      </item>
#     </item>
#     <item name="RecordStatus" type="String">
#      PubMed - indexed for MEDLINE
#     </item>
#     <item name="PubStatus" type="String">
#      ppublish
#     </item>
#     <item name="ArticleIds" type="List">
#      <item name="pubmed" type="String">
#       8072976
#      </item>
#     </item>
#     <item name="History" type="List">
#      <item name="pubmed" type="Date">
#       1994/04/16 00:00
#      </item>
#      <item name="medline" type="Date">
#       1994/04/16 00:01
#      </item>
#      <item name="entrez" type="Date">
#       1994/04/16 00:00
#      </item>
#     </item>
#     <item name="References" type="List">
#     </item>
#     <item name="HasAbstract" type="Integer">
#      1
#     </item>
#     <item name="PmcRefCount" type="Integer">
#      0
#     </item>
#     <item name="FullJournalName" type="String">
#      Presse medicale (Paris, France : 1983)
#     </item>
#     <item name="ELocationID" type="String">
#     </item>
#     <item name="SO" type="String">
#      1994 Apr 16;23(15):707-9
#     </item>
#    </docsum>
#    <docsum>
#     <id>
#      8352260
#     </id>
#     <item name="PubDate" type="Date">
#      1993 Aug
#     </item>
#     <item name="EPubDate" type="Date">
#     </item>
#     <item name="Source" type="String">
#      Am J Kidney Dis
#     </item>
#     <item name="AuthorList" type="List">
#      <item name="Author" type="String">
#       Neumayer HH
#      </item>
#      <item name="Author" type="String">
#       Kienbaum M
#      </item>
#      <item name="Author" type="String">
#       Graf S
#      </item>
#      <item name="Author" type="String">
#       Schreiber M
#      </item>
#      <item name="Author" type="String">
#       Mann JF
#      </item>
#      <item name="Author" type="String">
#       Luft FC
#      </item>
#     </item>
#     <item name="LastAuthor" type="String">
#      Luft FC
#     </item>
#     <item name="Title" type="String">
#      Prevalence and long-term outcome of glomerulonephritis in renal allografts.
#     </item>
#     <item name="Volume" type="String">
#      22
#     </item>
#     <item name="Issue" type="String">
#      2
#     </item>
#     <item name="Pages" type="String">
#      320-5
#     </item>
#     <item name="LangList" type="List">
#      <item name="Lang" type="String">
#       English
#      </item>
#     </item>
#     <item name="NlmUniqueID" type="String">
#      8110075
#     </item>
#     <item name="ISSN" type="String">
#      0272-6386
#     </item>
#     <item name="ESSN" type="String">
#     </item>
#     <item name="PubTypeList" type="List">
#      <item name="PubType" type="String">
#       Journal Article
#      </item>
#     </item>
#     <item name="RecordStatus" type="String">
#      PubMed - indexed for MEDLINE
#     </item>
#     <item name="PubStatus" type="String">
#      ppublish
#     </item>
#     <item name="ArticleIds" type="List">
#      <item name="pubmed" type="String">
#       8352260
#      </item>
#      <item name="doi" type="String">
#       10.1016/s0272-6386(12)70325-6
#      </item>
#      <item name="pii" type="String">
#       S0272638693001696
#      </item>
#     </item>
#     <item name="DOI" type="String">
#      10.1016/s0272-6386(12)70325-6
#     </item>
#     <item name="History" type="List">
#      <item name="pubmed" type="Date">
#       1993/08/01 00:00
#      </item>
#      <item name="medline" type="Date">
#       1993/08/01 00:01
#      </item>
#      <item name="entrez" type="Date">
#       1993/08/01 00:00
#      </item>
#     </item>
#     <item name="References" type="List">
#     </item>
#     <item name="HasAbstract" type="Integer">
#      1
#     </item>
#     <item name="PmcRefCount" type="Integer">
#      0
#     </item>
#     <item name="FullJournalName" type="String">
#      American journal of kidney diseases : the official journal of the National Kidney Foundation
#     </item>
#     <item name="ELocationID" type="String">
#     </item>
#     <item name="SO" type="String">
#      1993 Aug;22(2):320-5
#     </item>
#    </docsum>
#    <docsum>
#     <id>
#      1465661
#     </id>
#     <item name="PubDate" type="Date">
#      1992 Mar-Apr
#     </item>
#     <item name="EPubDate" type="Date">
#     </item>
#     <item name="Source" type="String">
#      Srp Arh Celok Lek
#     </item>
#     <item name="AuthorList" type="List">
#      <item name="Author" type="String">
#       Peco-Antić A
#      </item>
#      <item name="Author" type="String">
#       Popović-Rolović M
#      </item>
#      <item name="Author" type="String">
#       Jovanović O
#      </item>
#      <item name="Author" type="String">
#       Kostić M
#      </item>
#      <item name="Author" type="String">
#       Popović D
#      </item>
#     </item>
#     <item name="LastAuthor" type="String">
#      Popović D
#     </item>
#     <item name="Title" type="String">
#      [Cyclosporine in the treatment of glomerular diseases in children].
#     </item>
#     <item name="Volume" type="String">
#      120
#     </item>
#     <item name="Issue" type="String">
#      3-4
#     </item>
#     <item name="Pages" type="String">
#      132-6
#     </item>
#     <item name="LangList" type="List">
#      <item name="Lang" type="String">
#       srp
#      </item>
#     </item>
#     <item name="NlmUniqueID" type="String">
#      0027440
#     </item>
#     <item name="ISSN" type="String">
#      0370-8179
#     </item>
#     <item name="ESSN" type="String">
#     </item>
#     <item name="PubTypeList" type="List">
#      <item name="PubType" type="String">
#       Journal Article
#      </item>
#     </item>
#     <item name="RecordStatus" type="String">
#      PubMed - indexed for MEDLINE
#     </item>
#     <item name="PubStatus" type="String">
#      ppublish
#     </item>
#     <item name="ArticleIds" type="List">
#      <item name="pubmed" type="String">
#       1465661
#      </item>
#     </item>
#     <item name="History" type="List">
#      <item name="pubmed" type="Date">
#       1992/03/01 00:00
#      </item>
#      <item name="medline" type="Date">
#       1992/03/01 00:01
#      </item>
#      <item name="entrez" type="Date">
#       1992/03/01 00:00
#      </item>
#     </item>
#     <item name="References" type="List">
#     </item>
#     <item name="HasAbstract" type="Integer">
#      1
#     </item>
#     <item name="PmcRefCount" type="Integer">
#      0
#     </item>
#     <item name="FullJournalName" type="String">
#      Srpski arhiv za celokupno lekarstvo
#     </item>
#     <item name="ELocationID" type="String">
#     </item>
#     <item name="SO" type="String">
#      1992 Mar-Apr;120(3-4):132-6
#     </item>
#    </docsum>
#    <docsum>
#     <id>
#      2033905
#     </id>
#     <item name="PubDate" type="Date">
#      1991 Mar-Apr
#     </item>
#     <item name="EPubDate" type="Date">
#     </item>
#     <item name="Source" type="String">
#      Klin Padiatr
#     </item>
#     <item name="AuthorList" type="List">
#      <item name="Author" type="String">
#       Lettgen B
#      </item>
#      <item name="Author" type="String">
#       Rascher W
#      </item>
#     </item>
#     <item name="LastAuthor" type="String">
#      Rascher W
#     </item>
#     <item name="Title" type="String">
#      [Acute reversible kidney failure in IgA nephritis].
#     </item>
#     <item name="Volume" type="String">
#      203
#     </item>
#     <item name="Issue" type="String">
#      2
#     </item>
#     <item name="Pages" type="String">
#      124-8
#     </item>
#     <item name="LangList" type="List">
#      <item name="Lang" type="String">
#       German
#      </item>
#     </item>
#     <item name="NlmUniqueID" type="String">
#      0326144
#     </item>
#     <item name="ISSN" type="String">
#      0300-8630
#     </item>
#     <item name="ESSN" type="String">
#     </item>
#     <item name="PubTypeList" type="List">
#      <item name="PubType" type="String">
#       Journal Article
#      </item>
#     </item>
#     <item name="RecordStatus" type="String">
#      PubMed - indexed for MEDLINE
#     </item>
#     <item name="PubStatus" type="String">
#      ppublish
#     </item>
#     <item name="ArticleIds" type="List">
#      <item name="pubmed" type="String">
#       2033905
#      </item>
#      <item name="doi" type="String">
#       10.1055/s-2007-1025414
#      </item>
#     </item>
#     <item name="DOI" type="String">
#      10.1055/s-2007-1025414
#     </item>
#     <item name="History" type="List">
#      <item name="pubmed" type="Date">
#       1991/03/01 00:00
#      </item>
#      <item name="medline" type="Date">
#       1991/03/01 00:01
#      </item>
#      <item name="entrez" type="Date">
#       1991/03/01 00:00
#      </item>
#     </item>
#     <item name="References" type="List">
#     </item>
#     <item name="HasAbstract" type="Integer">
#      1
#     </item>
#     <item name="PmcRefCount" type="Integer">
#      0
#     </item>
#     <item name="FullJournalName" type="String">
#      Klinische Padiatrie
#     </item>
#     <item name="ELocationID" type="String">
#     </item>
#     <item name="SO" type="String">
#      1991 Mar-Apr;203(2):124-8
#     </item>
#    </docsum>
#    <docsum>
#     <id>
#      2149742
#     </id>
#     <item name="PubDate" type="Date">
#      1990 Nov
#     </item>
#     <item name="EPubDate" type="Date">
#     </item>
#     <item name="Source" type="String">
#      Monatsschr Kinderheilkd
#     </item>
#     <item name="AuthorList" type="List">
#      <item name="Author" type="String">
#       Lettgen B
#      </item>
#      <item name="Author" type="String">
#       Rascher W
#      </item>
#     </item>
#     <item name="LastAuthor" type="String">
#      Rascher W
#     </item>
#     <item name="Title" type="String">
#      [IgA nephritis: a frequent form of glomerulonephritis in childhood].
#     </item>
#     <item name="Volume" type="String">
#      138
#     </item>
#     <item name="Issue" type="String">
#      11
#     </item>
#     <item name="Pages" type="String">
#      730-4
#     </item>
#     <item name="LangList" type="List">
#      <item name="Lang" type="String">
#       German
#      </item>
#     </item>
#     <item name="NlmUniqueID" type="String">
#      8206462
#     </item>
#     <item name="ISSN" type="String">
#      0026-9298
#     </item>
#     <item name="ESSN" type="String">
#     </item>
#     <item name="PubTypeList" type="List">
#      <item name="PubType" type="String">
#       Journal Article
#      </item>
#      <item name="PubType" type="String">
#       Review
#      </item>
#     </item>
#     <item name="RecordStatus" type="String">
#      PubMed - indexed for MEDLINE
#     </item>
#     <item name="PubStatus" type="String">
#      ppublish
#     </item>
#     <item name="ArticleIds" type="List">
#      <item name="pubmed" type="String">
#       2149742
#      </item>
#     </item>
#     <item name="History" type="List">
#      <item name="pubmed" type="Date">
#       1990/11/01 00:00
#      </item>
#      <item name="medline" type="Date">
#       1990/11/01 00:01
#      </item>
#      <item name="entrez" type="Date">
#       1990/11/01 00:00
#      </item>
#     </item>
#     <item name="References" type="List">
#     </item>
#     <item name="HasAbstract" type="Integer">
#      1
#     </item>
#     <item name="PmcRefCount" type="Integer">
#      0
#     </item>
#     <item name="FullJournalName" type="String">
#      Monatsschrift Kinderheilkunde : Organ der Deutschen Gesellschaft fur Kinderheilkunde
#     </item>
#     <item name="ELocationID" type="String">
#     </item>
#     <item name="SO" type="String">
#      1990 Nov;138(11):730-4
#     </item>
#    </docsum>
#   </esummaryresult>
#  </body>
# </html>
